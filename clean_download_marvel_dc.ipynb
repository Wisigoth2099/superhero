# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from google.colab import files

# %%
df = pd.read_csv("/content/drive/MyDrive/HETIC/ML/projet SH/df_taille_poid/marvel_and_dc.csv")
df.head()
# Out:
#              creator  height  ...  has_agility has_super_strength
# 0      Marvel Comics   203.0  ...          1.0                1.0
# 1  Dark Horse Comics   191.0  ...          1.0                1.0
# 2          DC Comics   185.0  ...          0.0                0.0
# 3      Marvel Comics   203.0  ...          1.0                1.0
# 4          DC Comics   183.0  ...          0.0                0.0
#
# [5 rows x 57 columns]

# %%
mask = df['creator'].isin(['Marvel Comics', 'DC Comics'])
df = df[mask]
df
# Out:
#             creator  height  ...  has_agility has_super_strength
# 0     Marvel Comics   203.0  ...          1.0                1.0
# 2         DC Comics   185.0  ...          0.0                0.0
# 3     Marvel Comics   203.0  ...          1.0                1.0
# 4         DC Comics   183.0  ...          0.0                0.0
# 5         DC Comics   198.0  ...          0.0                0.0
# ...             ...     ...  ...          ...                ...
# 1076  Marvel Comics   170.0  ...          NaN                NaN
# 1078      DC Comics   170.0  ...          0.0                0.0
# 1080      DC Comics   185.0  ...          1.0                1.0
# 1081      DC Comics   185.0  ...          0.0                0.0
# 1082  Marvel Comics  1220.0  ...          1.0                1.0
#
# [819 rows x 57 columns]

# %%
df = df.reset_index(drop=True)
df
# Out:
#            creator  height  ...  has_agility has_super_strength
# 0    Marvel Comics   203.0  ...          1.0                1.0
# 1        DC Comics   185.0  ...          0.0                0.0
# 2    Marvel Comics   203.0  ...          1.0                1.0
# 3        DC Comics   183.0  ...          0.0                0.0
# 4        DC Comics   198.0  ...          0.0                0.0
# ..             ...     ...  ...          ...                ...
# 814  Marvel Comics   170.0  ...          NaN                NaN
# 815      DC Comics   170.0  ...          0.0                0.0
# 816      DC Comics   185.0  ...          1.0                1.0
# 817      DC Comics   185.0  ...          0.0                0.0
# 818  Marvel Comics  1220.0  ...          1.0                1.0
#
# [819 rows x 57 columns]

# %%
df.to_csv('output.csv', index=False, encoding = 'utf-8-sig')
files.download('output.csv')
